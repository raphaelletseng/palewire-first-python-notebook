# %%
2+2
# Out:
# 4

# %%
2+3
# Out:
# 5

# %%
+2
# Out:
# 2

# %%
number = 5

# %%
number + 3
# Out:
# 8

# %% [markdown]
# ## 3. Pandas

# %%
import pandas as pd

# %%
my_list = [2,4,6,8,9,11,3]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 43

# %%
my_series.max()
# Out:
# 11

# %%
my_series.min()
# Out:
# 2

# %%
my_series.mean()
# Out:
# 6.142857142857143

# %%
my_series.describe()
# Out:
# count     7.000000
# mean      6.142857
# std       3.338092
# min       2.000000
# 25%       3.500000
# 50%       6.000000
# 75%       8.500000
# max      11.000000
# dtype: float64

# %% [markdown]
# ## 4. Data

# %% [markdown]
# LA Times, The Robinson R44

# %%
accident_list = pd.read_csv("https://raw.githubusercontent.com/palewire/first-python-notebook/main/docs/src/_static/ntsb-accidents.csv")

# %%
accident_list
# Out:
#            event_id                       ntsb_make ntsb_model ntsb_number  \
# 0    20061222X01838                            BELL        407  NYC07FA048
# 1    20060817X01187                        ROBINSON   R22 BETA  LAX06LA257
# 2    20060111X00044                        ROBINSON        R44  MIA06FA039
# 3    20060419X00461                        ROBINSON     R44 II  DFW06FA102
# 4    20060208X00181                        ROBINSON        R44  SEA06LA052
# ..              ...                             ...        ...         ...
# 158  20160711X32921  BELL HELICOPTER TEXTRON CANADA        407  ERA16FA248
# 159  20160804X45514                       SCHWEIZER     269C 1  CEN16FA304
# 160  20160404X74644                            BELL        206  ERA16FA144
# 161  20160507X31120                          AIRBUS      AS350  ANC16FA023
# 162  20160612X85856     ROBINSON HELICOPTER COMPANY     R44 II  CEN16FA215
#
# ...

# %%
accident_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                163 non-null    object
#  1   ntsb_make               163 non-null    object
#  2   ntsb_model              163 non-null    object
#  3   ntsb_number             163 non-null    object
#  4   year                    163 non-null    int64
#  5   date                    163 non-null    object
#  6   city                    163 non-null    object
#  7   state                   162 non-null    object
#  8   country                 163 non-null    object
#  9   total_fatalities        163 non-null    int64
#  10  latimes_make            163 non-null    object
#  11  latimes_model           163 non-null    object
#  12  latimes_make_and_model  163 non-null    object
# dtypes: int64(2), object(11)
# memory usage: 16.7+ KB

# %%
accident_list['latimes_make_and_model']
# Out:
# 0           BELL 407
# 1       ROBINSON R22
# 2       ROBINSON R44
# 3       ROBINSON R44
# 4       ROBINSON R44
#            ...
# 158         BELL 407
# 159    SCHWEIZER 269
# 160         BELL 206
# 161       AIRBUS 350
# 162     ROBINSON R44
# Name: latimes_make_and_model, Length: 163, dtype: object

# %%
accident_list.latimes_make_and_model.value_counts()
# Out:
# latimes_make_and_model
# ROBINSON R44             38
# BELL 206                 30
# AIRBUS 350               29
# ROBINSON R22             20
# BELL 407                 13
# HUGHES 369               13
# MCDONNELL DOUGLAS 369     6
# SCHWEIZER 269             5
# AIRBUS 135                4
# SIKORSKY 76               2
# AGUSTA 109                2
# AIRBUS 130                1
# Name: count, dtype: int64

# %%
# Convert ugly Series into a pretty DataFrame by adding reset_index:
accident_list['latimes_make_and_model'].value_counts().reset_index()
# Out:
#    latimes_make_and_model  count
# 0            ROBINSON R44     38
# 1                BELL 206     30
# 2              AIRBUS 350     29
# 3            ROBINSON R22     20
# 4                BELL 407     13
# 5              HUGHES 369     13
# 6   MCDONNELL DOUGLAS 369      6
# 7           SCHWEIZER 269      5
# 8              AIRBUS 135      4
# 9             SIKORSKY 76      2
# 10             AGUSTA 109      2
# 11             AIRBUS 130      1

# %% [markdown]
# # Quick Challenge:
# What was the total number of fatalities? 336
#
# Which helicopter maker had the most accidents? ROBINSON
#
# What was the total number of helicopter accidents by year?
# 	year	count
# 0	2008	22
# 1	2006	20
# 2	2010	18
# 3	2013	18
# 4	2014	17
# 5	2007	16
# 6	2012	16
# 7	2009	15
# 8	2015	11
# 9	2016	10
#
# Which state had the most helicopter accidents? CA

# %%
list(accident_list)
# Out:
# ['event_id',
#  'ntsb_make',
#  'ntsb_model',
#  'ntsb_number',
#  'year',
#  'date',
#  'city',
#  'state',
#  'country',
#  'total_fatalities',
#  'latimes_make',
#  'latimes_model',
#  'latimes_make_and_model']

# %%
accident_list.total_fatalities.sum()
# Out:
# 336

# %%
accident_list.latimes_make.value_counts()
# Out:
# latimes_make
# ROBINSON             58
# BELL                 43
# AIRBUS               34
# HUGHES               13
# MCDONNELL DOUGLAS     6
# SCHWEIZER             5
# SIKORSKY              2
# AGUSTA                2
# Name: count, dtype: int64

# %%
accident_list['year'].value_counts().reset_index()
# Out:
#    year  count
# 0  2008     22
# 1  2006     20
# 2  2010     18
# 3  2013     18
# 4  2014     17
# 5  2007     16
# 6  2012     16
# 7  2009     15
# 8  2015     11
# 9  2016     10

# %%
accident_list.state.value_counts().reset_index()
# Out:
#    state  count
# 0     CA     16
# 1     TX     15
# 2     AZ     14
# 3     FL      9
# 4     WA      8
# 5     LA      8
# 6     TN      6
# 7     AK      6
# 8     AL      5
# 9     UT      5
# 10    OK      5
# 11    MT      4
# 12    HI      4
# 13    MO      4
# 14    OR      4
# 15    GM      3
# 16    WI      3
# 17    KY      3
# 18    PA      3
# 19    NM      3
# 20    CO      3
# 21    IA      3
# 22    IN      2
# 23    NV      2
# 24    NC      2
# 25    MD      2
# 26    AR      2
# 27    VA      2
# 28    MS      2
# 29    NY      2
# 30    MA      1
# 31    WV      1
# 32    WY      1
# 33    DE      1
# 34    GA      1
# 35    KS      1
# 36    NJ      1
# 37    SC      1
# 38    MI      1
# 39    DC      1
# 40    ID      1
# 41    PR      1

# %% [markdown]
# ## 6. Filter

# %%
my_state = 'MI'

# %%
mi_accidents = accident_list[accident_list['state'] == my_state]

# %%
mi_accidents.head()
# Out:
#           event_id ntsb_make ntsb_model ntsb_number  year               date  \
# 11  20060419X00457  ROBINSON   R22 BETA  CHI06FA109  2006  04/13/06 00:00:00
#
#        city state country  total_fatalities latimes_make latimes_model  \
# 11  CHELSEA    MI     USA                 2     ROBINSON           R22
#
#    latimes_make_and_model
# 11           ROBINSON R22

# %%
mi_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 11 to 11
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                1 non-null      object
#  1   ntsb_make               1 non-null      object
#  2   ntsb_model              1 non-null      object
#  3   ntsb_number             1 non-null      object
#  4   year                    1 non-null      int64
#  5   date                    1 non-null      object
#  6   city                    1 non-null      object
#  7   state                   1 non-null      object
#  8   country                 1 non-null      object
#  9   total_fatalities        1 non-null      int64
#  10  latimes_make            1 non-null      object
#  11  latimes_model           1 non-null      object
#  12  latimes_make_and_model  1 non-null      object
# dtypes: int64(2), object(11)
# memory usage: 112.0+ bytes

# %%
def get_state_result(fstate):
    state_accidents = accident_list[accident_list['state'] == fstate]
    print(len(state_accidents))
    print(state_accidents.info())

# %%
get_state_result('IA')
# Out:
# 3
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 12 to 140
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                3 non-null      object
#  1   ntsb_make               3 non-null      object
#  2   ntsb_model              3 non-null      object
#  3   ntsb_number             3 non-null      object
#  4   year                    3 non-null      int64
#  5   date                    3 non-null      object
#  6   city                    3 non-null      object
#  7   state                   3 non-null      object
#  8   country                 3 non-null      object
#  9   total_fatalities        3 non-null      int64
#  10  latimes_make            3 non-null      object
#  11  latimes_model           3 non-null      object
#  12  latimes_make_and_model  3 non-null      object
# dtypes: int64(2), object(11)
# memory usage: 336.0+ bytes
# None

# %%
get_state_result('MO')
# Out:
# 4
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 55 to 144
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                4 non-null      object
#  1   ntsb_make               4 non-null      object
#  2   ntsb_model              4 non-null      object
#  3   ntsb_number             4 non-null      object
#  4   year                    4 non-null      int64
#  5   date                    4 non-null      object
#  6   city                    4 non-null      object
#  7   state                   4 non-null      object
#  8   country                 4 non-null      object
#  9   total_fatalities        4 non-null      int64
#  10  latimes_make            4 non-null      object
#  11  latimes_model           4 non-null      object
#  12  latimes_make_and_model  4 non-null      object
# dtypes: int64(2), object(11)
# memory usage: 448.0+ bytes
# None

# %% [markdown]
# Which state recorded more accidents, Iowa or Missouri? Missouri (MO)
#
# How many accidents recorded more than one fatality? 89
#
# How many accidents happened in California in 2015? 2
#
# What percentage of the total fatalities occured in California? 9.5%

# %%
accident_list[accident_list['total_fatalities'] >= 2]
# Out:
#            event_id           ntsb_make ntsb_model ntsb_number  year  \
# 0    20061222X01838                BELL        407  NYC07FA048  2006
# 2    20060111X00044            ROBINSON        R44  MIA06FA039  2006
# 3    20060419X00461            ROBINSON     R44 II  DFW06FA102  2006
# 5    20060228X00255            ROBINSON        R22  ANC06FA020  2006
# 6    20060824X01237          EUROCOPTER  AS-350-B3  SEA06GA158  2006
# ..              ...                 ...        ...         ...   ...
# 150  20151216X13718  AIRBUS HELICOPTERS      AS350  WPR16FA040  2015
# 152  20151118X05037  AIRBUS HELICOPTERS   AS350B3E  WPR16FA029  2015
# 153  20161116X00108              HUGHES  369D/500D  WPR17FA021  2016
# 154  20160326X80544          EUROCOPTER  AS 350 B2  ERA16FA140  2016
# 160  20160404X74644                BELL        206  ERA16FA144  2016
#
#                   date            city state country  total_fatalities  \
# ...

# %%
accident_list[(accident_list['state'] == 'CA') & (accident_list['year'] == 2015)]
# Out:
#            event_id           ntsb_make ntsb_model ntsb_number  year  \
# 148  20151211X13514                BELL        407  WPR16FA037  2015
# 152  20151118X05037  AIRBUS HELICOPTERS   AS350B3E  WPR16FA029  2015
#
#                   date       city state country  total_fatalities  \
# 148  12/10/15 00:00:00  MCFARLAND    CA     USA                 4
# 152  11/18/15 00:00:00   CARLSBAD    CA     USA                 2
#
#     latimes_make latimes_model latimes_make_and_model
# 148         BELL           407               BELL 407
# 152       AIRBUS           350             AIRBUS 350

# %%
total_fatalities_ca = accident_list[(accident_list['state'] == 'CA') & (accident_list['total_fatalities'] > 0)].total_fatalities.sum()

# %%
(total_fatalities_ca/accident_list.total_fatalities.sum())*100
# Out:
# 9.523809523809524

# %% [markdown]
# ## 7. Group

# %%
accident_counts = accident_list.groupby(['latimes_make', 'latimes_make_and_model']).size().rename('accidents').reset_index() # size gives total, similar to value_counts

# %%
# sum total fatalities for each maker
accident_list.groupby('latimes_make_and_model')['total_fatalities'].sum().reset_index()
# Out:
#    latimes_make_and_model  total_fatalities
# 0              AGUSTA 109                 5
# 1              AIRBUS 130                 1
# 2              AIRBUS 135                11
# 3              AIRBUS 350                81
# 4                BELL 206                61
# 5                BELL 407                35
# 6              HUGHES 369                19
# 7   MCDONNELL DOUGLAS 369                 7
# 8            ROBINSON R22                27
# 9            ROBINSON R44                71
# 10          SCHWEIZER 269                 7
# 11            SIKORSKY 76                11

# %%
accident_counts.head()
# Out:
#   latimes_make latimes_make_and_model  accidents
# 0       AGUSTA             AGUSTA 109          2
# 1       AIRBUS             AIRBUS 130          1
# 2       AIRBUS             AIRBUS 135          4
# 3       AIRBUS             AIRBUS 350         29
# 4         BELL               BELL 206         30

# %% [markdown]
# ## 8. Merge

# %%
survey = pd.read_csv("https://raw.githubusercontent.com/palewire/first-python-notebook/main/docs/src/_static/faa-survey.csv")

# %%
survey.head()
# Out:
#   latimes_make_and_model  total_hours
# 0             AGUSTA 109       362172
# 1             AIRBUS 130      1053786
# 2             AIRBUS 135       884596
# 3             AIRBUS 350      3883490
# 4               BELL 206      5501308

# %%
accident_counts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   latimes_make            12 non-null     object
#  1   latimes_make_and_model  12 non-null     object
#  2   accidents               12 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 416.0+ bytes

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   latimes_make_and_model  12 non-null     object
#  1   total_hours             12 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 320.0+ bytes

# %%
merged_list = pd.merge(accident_counts, survey, on="latimes_make_and_model")

# %%
merged_list.head()
# Out:
#   latimes_make latimes_make_and_model  accidents  total_hours
# 0       AGUSTA             AGUSTA 109          2       362172
# 1       AIRBUS             AIRBUS 130          1      1053786
# 2       AIRBUS             AIRBUS 135          4       884596
# 3       AIRBUS             AIRBUS 350         29      3883490
# 4         BELL               BELL 206         30      5501308

# %%
merged_list.info() # if there are no null values, that means every record in each df found a match in the other
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   latimes_make            12 non-null     object
#  1   latimes_make_and_model  12 non-null     object
#  2   accidents               12 non-null     int64
#  3   total_hours             12 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 512.0+ bytes

# %% [markdown]
# ## 9. Compute
# creating a new column based on data in other colums is a process known as computing

# %%
merged_list['per_hour'] = merged_list['accidents']/merged_list['total_hours']

# %%
merged_list.head()
# Out:
#   latimes_make latimes_make_and_model  accidents  total_hours      per_hour
# 0       AGUSTA             AGUSTA 109          2       362172  5.522238e-06
# 1       AIRBUS             AIRBUS 130          1      1053786  9.489593e-07
# 2       AIRBUS             AIRBUS 135          4       884596  4.521838e-06
# 3       AIRBUS             AIRBUS 350         29      3883490  7.467510e-06
# 4         BELL               BELL 206         30      5501308  5.453249e-06

# %%
merged_list['per_100k_hours'] = merged_list['per_hour'] * 100_000

# %%
merged_list.head()
# Out:
#   latimes_make latimes_make_and_model  accidents  total_hours      per_hour  \
# 0       AGUSTA             AGUSTA 109          2       362172  5.522238e-06
# 1       AIRBUS             AIRBUS 130          1      1053786  9.489593e-07
# 2       AIRBUS             AIRBUS 135          4       884596  4.521838e-06
# 3       AIRBUS             AIRBUS 350         29      3883490  7.467510e-06
# 4         BELL               BELL 206         30      5501308  5.453249e-06
#
#    per_100k_hours
# 0        0.552224
# 1        0.094896
# 2        0.452184
# 3        0.746751
# 4        0.545325

# %% [markdown]
# ## 10. Sort

# %%
merged_list.sort_values('per_100k_hours', ascending=False) # ascending = False to get highest value at the top
# Out:
#          latimes_make latimes_make_and_model  accidents  total_hours  \
# 9            ROBINSON           ROBINSON R44         38      2359729
# 7   MCDONNELL DOUGLAS  MCDONNELL DOUGLAS 369          6       550689
# 6              HUGHES             HUGHES 369         13      1201688
# 3              AIRBUS             AIRBUS 350         29      3883490
# 8            ROBINSON           ROBINSON R22         20      2970806
# 5                BELL               BELL 407         13      2113788
# 0              AGUSTA             AGUSTA 109          2       362172
# 4                BELL               BELL 206         30      5501308
# 2              AIRBUS             AIRBUS 135          4       884596
# 10          SCHWEIZER          SCHWEIZER 269          5      1139326
# 11           SIKORSKY            SIKORSKY 76          2       915515
# 1              AIRBUS             AIRBUS 130          1      1053786
#
#         per_hour  per_100k_hours
# 9   1.610354e-05        1.610354
# ...

# %% [markdown]
# ## 11. Charts

# %%
pip install altair
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ghgsat.com/simple/
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt

# %%
alt.Chart(merged_list).mark_bar().encode(y="latimes_make_and_model", x="per_100k_hours")
# Out:
# alt.Chart(...)

# %%
alt.Chart(merged_list).mark_bar().encode(x="per_100k_hours", y=alt.Y("latimes_make_and_model", sort="-x")).properties(title="Helicopter accident rates")
# Out:
# alt.Chart(...)

# %%
alt.Chart(merged_list).mark_circle().encode(size="per_100k_hours", y=alt.Y("latimes_make_and_model", sort="-size"), tooltip="per_100k_hours")
# Out:
# alt.Chart(...)

# %%
alt.Chart(merged_list).mark_bar().encode(x='per_100k_hours',y=alt.Y('latimes_make_and_model', sort='-x'), color='latimes_make').properties(title="Helicopter accident rates")
# Out:
# alt.Chart(...)

# %%
alt.Chart(merged_list).mark_bar().encode(x='per_100k_hours',
                                         y=alt.Y('latimes_make_and_model', sort='-x'), 
                                         color=alt.condition(
                                             alt.datum.latimes_make=="ROBINSON",
                                             alt.value("purple"),
                                             alt.value('pink')
                                         )
                                        ).properties(title="Helicopter accident rates")
# Out:
# alt.Chart(...)

# %%
#convert an object type to a date type 
accident_list['date'] = pd.to_datetime(accident_list['date'])

# %%
alt.Chart(accident_list).mark_bar().encode(x="date", y="total_fatalities")
# Out:
# alt.Chart(...)

# %%
alt.Chart(accident_list).mark_bar().encode(x="yearmonth(date)", y="sum(total_fatalities)")
# Out:
# alt.Chart(...)

# %%
alt.Chart(accident_list).mark_bar().encode(x="yearmonth(date)", y="sum(total_fatalities)", facet="latimes_make")
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 12. Export

# %%
merged_list.to_csv('accident-rate-ranking.csv', index=False, sep=";")

# %% [markdown]
# ![datawrapper](datawrapper-accident-rate-ranking.png)

# %%
# https://palewi.re/docs/first-python-notebook/appendix/index.html

# %% [markdown]
# ## SUMMARY of things we learnt

# %% [markdown]
# - Panda series turn lists into more useful things that we can `.max(), .min(), .sum(), .mean(), .describe()`
# - You can import data from a url using `pd.read_csv(url)`
# - A Series in 1 dimensional, and a dataframe is 2 dimensional
# - df.info() tells you stuff about the df
# - You can do lots of things with dataframes! Eg. `df['column']` or df.column to list a specific column. Then you can append `.sum()` to a specific column to total that column, or add `.value_counts()` to sum up the different values in that column.
# - `.reset_index()` turns un ugly series into a pretty dataframe
# - `list(df)` gives you all the column headers of the df
# - `df.head()` gives you the first 5 entries in a df. You can tailor this to get more or less by adding a number to the function eg. `df.head(1)` will only return the first entry. Good habit to get into if you want to take a quick look without loading all the data.
# -  You can filter what you get back from a df by doing `df[df['column'] == x]` where x is a value in that column
# -  You can have two filters by doing `df[(df['col1'] == 'x') & (df['col2'] == y)]`, don't forget brackets!
# -  You can append `.col_name.sum()` to the filter condition to only return the total of a specified column
# -  `len(df)` will give you the number of entries / rows in the df
# -  You can group things too: `new_counts = df.groupby(['col1', 'col2']).size().rename('new_name').reset_index() # size gives total number of instances, similar to value_counts`
#
#
# ### Merging two pds:
# 1. Get second df using `df2 = pd.read_csv(url2)`
# 2. Use `df1.info()` and `df2.info()` to find a shared_column these two dfs can be joined on
# 3. Do `merged_list = pd.merge(df1, df2, on="shared_column")`
#
# - Compute a new Column: `merged_list['new_col_name'] = merged_list['col1']/merged_list['col2']`
# - Sort: `merged_list.sort_values('col1', ascending=False) # ascending = False to get highest value at the top`
#
# ### Charts with Altair
# `import altair as alt`
# `alt.Chart(merged_list).mark_bar().encode(x="col1", y=alt.Y("col2", sort="-x")).properties(title="TITLE")`
# ```
# alt.Chart(merged_list).mark_bar().encode(x='col1',
#                                          y=alt.Y('col2', sort='-x'),
#                                          color=alt.condition(
#                                              alt.datum.col2=="VALUE",
#                                              alt.value("purple"),
#                                              alt.value('pink')
#                                          )
#                                         ).properties(title="TITLE")
# ```
#
# - Specify the type of a column eg. object to datetime: `df['date'] = pd.to_datetime(accident_list['date'])`
# `alt.Chart(df).mark_bar().encode(x="yearmonth(date)", y="sum(col1)")`
#
# - Export data: `merged_list.to_csv('title.csv', index=False, sep=";")`
